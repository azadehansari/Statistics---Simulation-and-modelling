# %% [markdown]
# ## Python statistics essential training - 07_challenge

# %% [markdown]
# Standard imports

# %%
import math

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import statsmodels
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# Loading gapminder data for year 1985 (Live Aid!).

# %%
gapminder = pd.read_csv('gapminder.csv')

# %%
gdata = gapminder.query('year == 1985')

# %% [markdown]
# Refactored plotting so that it works on arbitrary datasets.

# %%
def sc(data):
    return 1e-6 * data.population, data.region.map({'Africa': 'skyblue', 'Europe': 'gold',
                                                   'America': 'palegreen', 'Asia': 'coral'})

def plotdata(data=gdata):
    size, colors = sc(data)
    data.plot.scatter('age5_surviving','babies_per_woman',
                      c=colors,s=size,linewidths=0.5,edgecolor='k',alpha=0.5)
                      
def plotfit(fit,data=gdata):
    plotdata(data)

    size, colors = sc(data)
    plt.scatter(data.age5_surviving,fit.predict(data),
               c=colors,s=30,linewidths=0.5,edgecolor='k',marker='D')

# %% [markdown]
# Our cross-validation function

# %%
# we'll make a function that is generic in terms of formula and response variable
def cross_validate(data,formula,response,n=100):
    ret = []
    
    for i in range(n):
        shuffled = data.sample(len(data))
        
        training = shuffled.iloc[:len(data)//2]
        testing = shuffled.iloc[len(data)//2:]
        
        trained = smf.ols(formula,data=training).fit()
        
        resid = trained.predict(testing) - testing[response]
        df = len(testing) - trained.df_model - 1
        mse = np.sum(resid**2) / df
    
        ret.append(mse)
    
    return np.mean(ret)

# %% [markdown]
# The best model formula we've found

# %%
f_surviving = 'babies_per_woman ~ -1 + region + age5_surviving'

# %%
fit = smf.ols(f_surviving,gdata).fit()
plotfit(fit,gdata)
cross_validate(gdata,f_surviving,'babies_per_woman')
# Out:
# 1.0661299771846933

# %%
gdata['log_pop'] = np.log(gdata['population'])
gdata.head()
# Out:
# <ipython-input-16-bec0a2bab77d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdata['log_pop'] = np.log(gdata['population'])
#                  country  year   region  population  life_expectancy  \
# 50           Afghanistan  1985     Asia  11630498.0            45.21
# 131              Albania  1985   Europe   2966799.0            72.71
# 212              Algeria  1985   Africa  22565908.0            67.18
# 293               Angola  1985   Africa   9745209.0            47.50
# 374  Antigua and Barbuda  1985  America     65744.0            72.13
#
#      age5_surviving  babies_per_woman  gdp_per_capita  gdp_per_day    log_pop  \
# 50           78.400              7.68          1384.0     3.789185  16.269141
# 131          94.570              3.23          4267.0    11.682409  14.902994
# 212          92.880              5.98         11030.0    30.198494  16.931951
# 293          77.170              7.21          4117.0    11.271732  16.092286
# 374          96.946              2.09         11383.0    31.164956  11.093524
#
#         pop_sqrt
# 50   3410.351595
# 131  1722.439839
# 212  4750.358723
# 293  3121.731731
# 374   256.405928

# %%
f_new_model = 'babies_per_woman ~ -1 + region + age5_surviving + log_pop'

fit = smf.ols(f_new_model, gdata).fit()
plotfit(fit, gdata)
cross_validate(gdata, f_new_model, 'babies_per_woman')
# Out:
# 1.077973874569257

# %%
gdata['pop_sqrt'] = np.sqrt(gdata['population'])
gdata.head()
# Out:
# <ipython-input-19-d76153ca3ff7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdata['pop_sqrt'] = np.sqrt(gdata['population'])
#                  country  year   region  population  life_expectancy  \
# 50           Afghanistan  1985     Asia  11630498.0            45.21
# 131              Albania  1985   Europe   2966799.0            72.71
# 212              Algeria  1985   Africa  22565908.0            67.18
# 293               Angola  1985   Africa   9745209.0            47.50
# 374  Antigua and Barbuda  1985  America     65744.0            72.13
#
#      age5_surviving  babies_per_woman  gdp_per_capita  gdp_per_day    log_pop  \
# 50           78.400              7.68          1384.0     3.789185  16.269141
# 131          94.570              3.23          4267.0    11.682409  14.902994
# 212          92.880              5.98         11030.0    30.198494  16.931951
# 293          77.170              7.21          4117.0    11.271732  16.092286
# 374          96.946              2.09         11383.0    31.164956  11.093524
#
#         pop_sqrt
# 50   3410.351595
# 131  1722.439839
# 212  4750.358723
# 293  3121.731731
# 374   256.405928

# %%
f_new_model_2 = 'babies_per_woman ~ -1 + region + age5_surviving + pop_sqrt'

fit = smf.ols(f_new_model_2, gdata).fit()
plotfit(fit, gdata)
cross_validate(gdata, f_new_model_2, 'babies_per_woman')
# Out:
# 0.9701994685707787

# %% [markdown]
# Adding squared root of population improves the performance of the model.

# %%
f_new_model_3 = 'babies_per_woman ~ -1 + region + age5_surviving + pow(age5_surviving,2)'

fit = smf.ols(f_new_model_3, gdata).fit()
plotfit(fit, gdata)
cross_validate(gdata, f_new_model_3, 'babies_per_woman')
# Out:
# 0.923628343108819

# %% [markdown]
# Model 3 looks even better.
